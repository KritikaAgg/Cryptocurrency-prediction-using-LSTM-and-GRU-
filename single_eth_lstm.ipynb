# %%
import pandas as pd
import tensorflow as tf
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data = pd.read_csv('/content/drive/MyDrive/pbl research/ETH-USD.csv')
data.head()
# Out:
#          Date         Open         High          Low        Close  \
# 0  2022-08-11  1851.828369  1927.939209  1851.828369  1881.224121
# 1  2022-08-12  1880.899170  1957.552979  1860.083496  1957.246460
# 2  2022-08-13  1957.333984  2013.755737  1948.595215  1981.336548
# 3  2022-08-14  1981.782471  2022.791504  1919.010132  1936.802002
# 4  2022-08-15  1936.760498  2007.210327  1881.856812  1904.228149
#
#      Adj Close       Volume
# 0  1881.224121  23826986482
# 1  1957.246460  17168141904
# 2  1981.336548  16038975216
# 3  1936.802002  14062754456
# 4  1904.228149  20349931313

# %%
# Drop the 'Date' column as it's not needed for modeling
data = data.drop(columns=['Date'])

# %%
# Normalize the data using Min-Max scaling
scaler = MinMaxScaler()
data_scaled = scaler.fit_transform(data)

# %%
# Define the number of time steps for the GRU model
time_steps = 10  # You can adjust this according to your need

# %%
# Prepare data with time steps
X = []
y = []
for i in range(len(data_scaled) - time_steps):
    X.append(data_scaled[i:i+time_steps, :])
    y.append(data_scaled[i+time_steps, 1])  # Assuming 'Open' price is the target

X = np.array(X)
y = np.array(y)

# %%
# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# %%
# Build the LSTM model
model = Sequential()
model.add(LSTM(64, activation='sigmoid', return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(LSTM(64, activation='sigmoid', return_sequences=True))
model.add(LSTM(64, activation='sigmoid', return_sequences=True))
model.add(LSTM(64, activation='sigmoid', return_sequences=True))
model.add(LSTM(64, activation='sigmoid'))
model.add(Dense(32, activation='sigmoid'))
model.add(Dense(1, activation='sigmoid'))

# %%
# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])

# %%
# Train the model
model.fit(X_train, y_train, epochs=50, batch_size=64, validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 5/5 [==============================] - 9s 251ms/step - loss: 0.1435 - mae: 0.3084 - val_loss: 0.0119 - val_mae: 0.0995
# Epoch 2/50
# 5/5 [==============================] - 0s 51ms/step - loss: 0.0919 - mae: 0.2484 - val_loss: 0.0489 - val_mae: 0.2115
# Epoch 3/50
# 5/5 [==============================] - 0s 52ms/step - loss: 0.0658 - mae: 0.2156 - val_loss: 0.1114 - val_mae: 0.3275
# Epoch 4/50
# 5/5 [==============================] - 0s 50ms/step - loss: 0.0644 - mae: 0.2226 - val_loss: 0.1460 - val_mae: 0.3767
# Epoch 5/50
# 5/5 [==============================] - 0s 55ms/step - loss: 0.0683 - mae: 0.2295 - val_loss: 0.1404 - val_mae: 0.3690
# Epoch 6/50
# 5/5 [==============================] - 0s 56ms/step - loss: 0.0657 - mae: 0.2247 - val_loss: 0.1144 - val_mae: 0.3320
# Epoch 7/50
# 5/5 [==============================] - 0s 61ms/step - loss: 0.0630 - mae: 0.2172 - val_loss: 0.0940 - val_mae: 0.2997
# Epoch 8/50
# 5/5 [==============================] - 0s 51ms/step - loss: 0.0626 - mae: 0.2137 - val_loss: 0.0845 - val_mae: 0.2835
# Epoch 9/50
# 5/5 [==============================] - 0s 53ms/step - loss: 0.0631 - mae: 0.2130 - val_loss: 0.0826 - val_mae: 0.2801
# Epoch 10/50
# 5/5 [==============================] - 0s 80ms/step - loss: 0.0630 - mae: 0.2131 - val_loss: 0.0896 - val_mae: 0.2923
# Epoch 11/50
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0627 - mae: 0.2141 - val_loss: 0.0975 - val_mae: 0.3054
# Epoch 12/50
# 5/5 [==============================] - 0s 82ms/step - loss: 0.0626 - mae: 0.2151 - val_loss: 0.0993 - val_mae: 0.3084
# Epoch 13/50
# 5/5 [==============================] - 0s 98ms/step - loss: 0.0626 - mae: 0.2153 - val_loss: 0.0982 - val_mae: 0.3067
# Epoch 14/50
# 5/5 [==============================] - 0s 79ms/step - loss: 0.0626 - mae: 0.2148 - val_loss: 0.0951 - val_mae: 0.3016
# Epoch 15/50
# 5/5 [==============================] - 0s 85ms/step - loss: 0.0626 - mae: 0.2143 - val_loss: 0.0919 - val_mae: 0.2963
# Epoch 16/50
# 5/5 [==============================] - 0s 82ms/step - loss: 0.0627 - mae: 0.2139 - val_loss: 0.0921 - val_mae: 0.2965
# Epoch 17/50
# 5/5 [==============================] - 0s 96ms/step - loss: 0.0628 - mae: 0.2140 - val_loss: 0.0907 - val_mae: 0.2942
# Epoch 18/50
# 5/5 [==============================] - 0s 81ms/step - loss: 0.0627 - mae: 0.2141 - val_loss: 0.0942 - val_mae: 0.3000
# Epoch 19/50
# 5/5 [==============================] - 0s 83ms/step - loss: 0.0627 - mae: 0.2142 - val_loss: 0.0920 - val_mae: 0.2963
# Epoch 20/50
# 5/5 [==============================] - 0s 95ms/step - loss: 0.0627 - mae: 0.2142 - val_loss: 0.0936 - val_mae: 0.2991
# Epoch 21/50
# 5/5 [==============================] - 0s 58ms/step - loss: 0.0626 - mae: 0.2143 - val_loss: 0.0955 - val_mae: 0.3023
# Epoch 22/50
# 5/5 [==============================] - 0s 52ms/step - loss: 0.0626 - mae: 0.2144 - val_loss: 0.0939 - val_mae: 0.2996
# Epoch 23/50
# 5/5 [==============================] - 0s 51ms/step - loss: 0.0626 - mae: 0.2142 - val_loss: 0.0930 - val_mae: 0.2981
# Epoch 24/50
# 5/5 [==============================] - 0s 52ms/step - loss: 0.0626 - mae: 0.2141 - val_loss: 0.0929 - val_mae: 0.2979
# Epoch 25/50
# 5/5 [==============================] - 0s 52ms/step - loss: 0.0627 - mae: 0.2140 - val_loss: 0.0924 - val_mae: 0.2970
# Epoch 26/50
# 5/5 [==============================] - 0s 55ms/step - loss: 0.0626 - mae: 0.2142 - val_loss: 0.0978 - val_mae: 0.3061
# Epoch 27/50
# 5/5 [==============================] - 0s 52ms/step - loss: 0.0627 - mae: 0.2153 - val_loss: 0.0990 - val_mae: 0.3079
# Epoch 28/50
# 5/5 [==============================] - 0s 53ms/step - loss: 0.0626 - mae: 0.2149 - val_loss: 0.0958 - val_mae: 0.3027
# Epoch 29/50
# 5/5 [==============================] - 0s 52ms/step - loss: 0.0626 - mae: 0.2143 - val_loss: 0.0932 - val_mae: 0.2983
# Epoch 30/50
# 5/5 [==============================] - 0s 55ms/step - loss: 0.0627 - mae: 0.2140 - val_loss: 0.0917 - val_mae: 0.2959
# Epoch 31/50
# 5/5 [==============================] - 0s 52ms/step - loss: 0.0628 - mae: 0.2138 - val_loss: 0.0888 - val_mae: 0.2910
# Epoch 32/50
# 5/5 [==============================] - 0s 51ms/step - loss: 0.0626 - mae: 0.2138 - val_loss: 0.0956 - val_mae: 0.3024
# Epoch 33/50
# 5/5 [==============================] - 0s 50ms/step - loss: 0.0626 - mae: 0.2150 - val_loss: 0.1024 - val_mae: 0.3134
# Epoch 34/50
# 5/5 [==============================] - 0s 52ms/step - loss: 0.0627 - mae: 0.2160 - val_loss: 0.1002 - val_mae: 0.3099
# Epoch 35/50
# 5/5 [==============================] - 0s 52ms/step - loss: 0.0627 - mae: 0.2148 - val_loss: 0.0899 - val_mae: 0.2927
# Epoch 36/50
# 5/5 [==============================] - 0s 55ms/step - loss: 0.0627 - mae: 0.2136 - val_loss: 0.0890 - val_mae: 0.2913
# Epoch 37/50
# 5/5 [==============================] - 0s 52ms/step - loss: 0.0627 - mae: 0.2136 - val_loss: 0.0910 - val_mae: 0.2948
# Epoch 38/50
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0628 - mae: 0.2147 - val_loss: 0.0976 - val_mae: 0.3057
# Epoch 39/50
# 5/5 [==============================] - 0s 52ms/step - loss: 0.0626 - mae: 0.2147 - val_loss: 0.0955 - val_mae: 0.3022
# Epoch 40/50
# 5/5 [==============================] - 0s 50ms/step - loss: 0.0626 - mae: 0.2145 - val_loss: 0.0962 - val_mae: 0.3033
# Epoch 41/50
# 5/5 [==============================] - 0s 50ms/step - loss: 0.0626 - mae: 0.2146 - val_loss: 0.0963 - val_mae: 0.3036
# Epoch 42/50
# 5/5 [==============================] - 0s 55ms/step - loss: 0.0628 - mae: 0.2146 - val_loss: 0.0941 - val_mae: 0.2999
# Epoch 43/50
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0626 - mae: 0.2141 - val_loss: 0.0944 - val_mae: 0.3005
# Epoch 44/50
# 5/5 [==============================] - 0s 51ms/step - loss: 0.0626 - mae: 0.2147 - val_loss: 0.0996 - val_mae: 0.3089
# Epoch 45/50
# 5/5 [==============================] - 0s 50ms/step - loss: 0.0627 - mae: 0.2156 - val_loss: 0.1019 - val_mae: 0.3127
# Epoch 46/50
# 5/5 [==============================] - 0s 59ms/step - loss: 0.0626 - mae: 0.2155 - val_loss: 0.0964 - val_mae: 0.3038
# Epoch 47/50
# 5/5 [==============================] - 0s 51ms/step - loss: 0.0626 - mae: 0.2142 - val_loss: 0.0892 - val_mae: 0.2917
# Epoch 48/50
# 5/5 [==============================] - 0s 53ms/step - loss: 0.0628 - mae: 0.2135 - val_loss: 0.0896 - val_mae: 0.2924
# Epoch 49/50
# 5/5 [==============================] - 0s 49ms/step - loss: 0.0627 - mae: 0.2144 - val_loss: 0.0997 - val_mae: 0.3091
# Epoch 50/50
# 5/5 [==============================] - 0s 66ms/step - loss: 0.0626 - mae: 0.2154 - val_loss: 0.1011 - val_mae: 0.3114

# %%
# Evaluate the model
loss, mae = model.evaluate(X_test, y_test)
print("Mean Absolute Error:", mae)
# Out:
# 3/3 [==============================] - 0s 10ms/step - loss: 0.1011 - mae: 0.3114
# Mean Absolute Error: 0.3114219307899475

# %%
# Make predictions
predictions = model.predict(X_test)
# Out:
# 3/3 [==============================] - 1s 9ms/step

# %%
# Inverse transform the predictions and true values to the original scale
predictions = scaler.inverse_transform(np.concatenate((X_test[:, -1, 1:], predictions), axis=1))[:, -1]
true_values = scaler.inverse_transform(np.concatenate((X_test[:, -1, 1:], y_test.reshape(-1, 1)), axis=1))[:, -1]

# %%
import matplotlib.pyplot as plt

# %%
# Plot predictions vs. true values
plt.figure(figsize=(12, 6))
plt.plot(predictions, label='Predictions', color='red')
plt.plot(true_values, label='True Values', color='blue')
plt.title('Bitcoin Price Prediction')
plt.xlabel('Time Steps')
plt.ylabel('Open Price')
plt.legend()
plt.show()

# %%
# Calculate percentage error
percentage_error = (abs(predictions - true_values) / true_values) * 100

# Print the percentage error
for i, error in enumerate(percentage_error):
    print(f"Sample {i+1}: Percentage Error = {error:.2f}%")

# Calculate and print the mean percentage error
mean_percentage_error = np.mean(percentage_error)
print("\nMean Percentage Error:", mean_percentage_error)
# Out:
# Sample 1: Percentage Error = 39.34%
# Sample 2: Percentage Error = 40.98%
# Sample 3: Percentage Error = 40.88%
# Sample 4: Percentage Error = 41.12%
# Sample 5: Percentage Error = 39.56%
# Sample 6: Percentage Error = 39.97%
# Sample 7: Percentage Error = 39.79%
# Sample 8: Percentage Error = 37.29%
# Sample 9: Percentage Error = 36.78%
# Sample 10: Percentage Error = 35.96%
# Sample 11: Percentage Error = 29.75%
# Sample 12: Percentage Error = 27.77%
# Sample 13: Percentage Error = 28.23%
# Sample 14: Percentage Error = 26.86%
# Sample 15: Percentage Error = 18.01%
# Sample 16: Percentage Error = 24.41%
# Sample 17: Percentage Error = 28.73%
# Sample 18: Percentage Error = 26.58%
# Sample 19: Percentage Error = 26.43%
# Sample 20: Percentage Error = 31.37%
# Sample 21: Percentage Error = 40.16%
# Sample 22: Percentage Error = 42.49%
# Sample 23: Percentage Error = 42.52%
# Sample 24: Percentage Error = 40.63%
# Sample 25: Percentage Error = 42.28%
# Sample 26: Percentage Error = 40.63%
# Sample 27: Percentage Error = 41.06%
# Sample 28: Percentage Error = 39.53%
# Sample 29: Percentage Error = 38.50%
# Sample 30: Percentage Error = 43.36%
# Sample 31: Percentage Error = 43.19%
# Sample 32: Percentage Error = 44.18%
# Sample 33: Percentage Error = 45.22%
# Sample 34: Percentage Error = 44.70%
# Sample 35: Percentage Error = 43.17%
# Sample 36: Percentage Error = 44.05%
# Sample 37: Percentage Error = 38.53%
# Sample 38: Percentage Error = 38.18%
# Sample 39: Percentage Error = 38.66%
# Sample 40: Percentage Error = 40.64%
# Sample 41: Percentage Error = 39.47%
# Sample 42: Percentage Error = 40.33%
# Sample 43: Percentage Error = 47.39%
# Sample 44: Percentage Error = 48.18%
# Sample 45: Percentage Error = 43.41%
# Sample 46: Percentage Error = 43.14%
# Sample 47: Percentage Error = 42.76%
# Sample 48: Percentage Error = 41.42%
# Sample 49: Percentage Error = 41.61%
# Sample 50: Percentage Error = 41.61%
# Sample 51: Percentage Error = 40.63%
# Sample 52: Percentage Error = 40.03%
# Sample 53: Percentage Error = 40.57%
# Sample 54: Percentage Error = 39.49%
# Sample 55: Percentage Error = 37.78%
# Sample 56: Percentage Error = 39.29%
# Sample 57: Percentage Error = 39.18%
# Sample 58: Percentage Error = 38.87%
# Sample 59: Percentage Error = 39.18%
# Sample 60: Percentage Error = 39.07%
# Sample 61: Percentage Error = 38.43%
# Sample 62: Percentage Error = 38.23%
# Sample 63: Percentage Error = 38.57%
# Sample 64: Percentage Error = 36.91%
# Sample 65: Percentage Error = 36.22%
# Sample 66: Percentage Error = 35.26%
# Sample 67: Percentage Error = 35.24%
# Sample 68: Percentage Error = 35.77%
# Sample 69: Percentage Error = 38.29%
# Sample 70: Percentage Error = 37.97%
# Sample 71: Percentage Error = 37.46%
# Sample 72: Percentage Error = 36.63%
#
# Mean Percentage Error: 38.33113124367844

# %%
# Make predictions
predictions = model.predict(X_test)

# Inverse transform the predictions and true values to the original scale
predictions = scaler.inverse_transform(np.concatenate((X_test[:, -1, 1:], predictions), axis=1))[:, -1]
true_values = scaler.inverse_transform(np.concatenate((X_test[:, -1, 1:], y_test.reshape(-1, 1)), axis=1))[:, -1]

# Define a threshold for investment decision
invest_threshold = 1.0  # You can adjust this threshold as needed
# Out:
# 3/3 [==============================] - 0s 9ms/step

# %%
# Determine investment decisions and print the results
for i in range(len(predictions)):
    if predictions[i] > X_test[i, -1, 1] * invest_threshold:
        decision = "Invest"
    else:
        decision = "Do not invest"

    print(f"Predicted Price: {predictions[i]:.2f} | Current Open Price: {X_test[i, -1, 1]:.2f} | Decision: {decision}")
# Out:
# Predicted Price: 19505285898.88 | Current Open Price: 0.77 | Decision: Invest
# Predicted Price: 19505291806.94 | Current Open Price: 0.75 | Decision: Invest
# Predicted Price: 19505386335.92 | Current Open Price: 0.77 | Decision: Invest
# Predicted Price: 19505478501.68 | Current Open Price: 0.77 | Decision: Invest
# Predicted Price: 19505536400.68 | Current Open Price: 0.77 | Decision: Invest
# Predicted Price: 19505398152.05 | Current Open Price: 0.75 | Decision: Invest
# Predicted Price: 19505391062.37 | Current Open Price: 0.76 | Decision: Invest
# Predicted Price: 19505343797.88 | Current Open Price: 0.76 | Decision: Invest
# Predicted Price: 19505269356.31 | Current Open Price: 0.72 | Decision: Invest
# Predicted Price: 19505206730.86 | Current Open Price: 0.72 | Decision: Invest
# Predicted Price: 19504975134.85 | Current Open Price: 0.71 | Decision: Invest
# Predicted Price: 19504744720.46 | Current Open Price: 0.64 | Decision: Invest
# Predicted Price: 19504540301.53 | Current Open Price: 0.62 | Decision: Invest
# Predicted Price: 19504372512.59 | Current Open Price: 0.62 | Decision: Invest
# Predicted Price: 19504047569.21 | Current Open Price: 0.61 | Decision: Invest
# Predicted Price: 19503747439.69 | Current Open Price: 0.54 | Decision: Invest
# Predicted Price: 19503650547.48 | Current Open Price: 0.59 | Decision: Invest
# Predicted Price: 19503644639.42 | Current Open Price: 0.63 | Decision: Invest
# Predicted Price: 19503591466.87 | Current Open Price: 0.61 | Decision: Invest
# Predicted Price: 19503561926.56 | Current Open Price: 0.61 | Decision: Invest
# Predicted Price: 19503683632.63 | Current Open Price: 0.66 | Decision: Invest
# Predicted Price: 19504041661.15 | Current Open Price: 0.76 | Decision: Invest
# Predicted Price: 19504368967.75 | Current Open Price: 0.79 | Decision: Invest
# Predicted Price: 19504625377.62 | Current Open Price: 0.80 | Decision: Invest
# Predicted Price: 19504829796.54 | Current Open Price: 0.77 | Decision: Invest
# Predicted Price: 19505059029.32 | Current Open Price: 0.79 | Decision: Invest
# Predicted Price: 19505164192.81 | Current Open Price: 0.77 | Decision: Invest
# Predicted Price: 19505290625.33 | Current Open Price: 0.77 | Decision: Invest
# Predicted Price: 19505289443.72 | Current Open Price: 0.75 | Decision: Invest
# Predicted Price: 19505297715.00 | Current Open Price: 0.74 | Decision: Invest
# Predicted Price: 19505463140.72 | Current Open Price: 0.81 | Decision: Invest
# Predicted Price: 19505597844.52 | Current Open Price: 0.81 | Decision: Invest
# Predicted Price: 19505686465.44 | Current Open Price: 0.82 | Decision: Invest
# Predicted Price: 19505817624.41 | Current Open Price: 0.84 | Decision: Invest
# Predicted Price: 19505894429.20 | Current Open Price: 0.83 | Decision: Invest
# Predicted Price: 19505882613.08 | Current Open Price: 0.81 | Decision: Invest
# Predicted Price: 19505796355.38 | Current Open Price: 0.82 | Decision: Invest
# Predicted Price: 19505690010.28 | Current Open Price: 0.74 | Decision: Invest
# Predicted Price: 19505640382.56 | Current Open Price: 0.74 | Decision: Invest
# Predicted Price: 19505594299.68 | Current Open Price: 0.74 | Decision: Invest
# Predicted Price: 19505569485.83 | Current Open Price: 0.77 | Decision: Invest
# Predicted Price: 19505530492.62 | Current Open Price: 0.75 | Decision: Invest
# Predicted Price: 19505490317.80 | Current Open Price: 0.76 | Decision: Invest
# Predicted Price: 19505699463.18 | Current Open Price: 0.87 | Decision: Invest
# Predicted Price: 19505828258.92 | Current Open Price: 0.89 | Decision: Invest
# Predicted Price: 19505848346.32 | Current Open Price: 0.81 | Decision: Invest
# Predicted Price: 19505881431.47 | Current Open Price: 0.80 | Decision: Invest
# Predicted Price: 19505884976.31 | Current Open Price: 0.80 | Decision: Invest
# Predicted Price: 19505864888.90 | Current Open Price: 0.78 | Decision: Invest
# Predicted Price: 19505842438.26 | Current Open Price: 0.78 | Decision: Invest
# Predicted Price: 19505822350.85 | Current Open Price: 0.78 | Decision: Invest
# Predicted Price: 19505792810.55 | Current Open Price: 0.77 | Decision: Invest
# Predicted Price: 19505704189.63 | Current Open Price: 0.76 | Decision: Invest
# Predicted Price: 19505652198.69 | Current Open Price: 0.77 | Decision: Invest
# Predicted Price: 19505542308.74 | Current Open Price: 0.75 | Decision: Invest
# Predicted Price: 19505450142.99 | Current Open Price: 0.73 | Decision: Invest
# Predicted Price: 19505422965.90 | Current Open Price: 0.75 | Decision: Invest
# Predicted Price: 19505391062.37 | Current Open Price: 0.75 | Decision: Invest
# Predicted Price: 19505376883.03 | Current Open Price: 0.74 | Decision: Invest
# Predicted Price: 19505389880.76 | Current Open Price: 0.75 | Decision: Invest
# Predicted Price: 19505361522.07 | Current Open Price: 0.75 | Decision: Invest
# Predicted Price: 19505322528.86 | Current Open Price: 0.74 | Decision: Invest
# Predicted Price: 19505303623.06 | Current Open Price: 0.74 | Decision: Invest
# Predicted Price: 19505261085.02 | Current Open Price: 0.74 | Decision: Invest
# Predicted Price: 19505197277.96 | Current Open Price: 0.72 | Decision: Invest
# Predicted Price: 19505134652.51 | Current Open Price: 0.71 | Decision: Invest
# Predicted Price: 19505085024.79 | Current Open Price: 0.70 | Decision: Invest
# Predicted Price: 19505037760.30 | Current Open Price: 0.70 | Decision: Invest
# Predicted Price: 19504986950.97 | Current Open Price: 0.71 | Decision: Invest
# Predicted Price: 19505014128.06 | Current Open Price: 0.74 | Decision: Invest
# Predicted Price: 19505044849.97 | Current Open Price: 0.73 | Decision: Invest
# Predicted Price: 19505053121.26 | Current Open Price: 0.73 | Decision: Invest

# %%
# Calculate daily price changes for true values and predictions
true_price_changes = true_values[1:] - true_values[:-1]
predicted_price_changes = predictions[1:] - true_values[:-1]

# Define a threshold for considering a change as profitable or in loss
profit_threshold = 0.0  # You can adjust this threshold based on your preference

# Calculate whether the predictions are in profit or loss
profit_or_loss = np.where(predicted_price_changes > profit_threshold, 'Profit', 'Loss')

# Print whether each prediction is in profit or loss
for i in range(len(profit_or_loss)):
    print(f"Prediction {i+1}: {profit_or_loss[i]}")
# Out:
# Prediction 1: Loss
# Prediction 2: Loss
# Prediction 3: Loss
# Prediction 4: Loss
# Prediction 5: Loss
# Prediction 6: Loss
# Prediction 7: Loss
# Prediction 8: Loss
# Prediction 9: Loss
# Prediction 10: Loss
# Prediction 11: Loss
# Prediction 12: Loss
# Prediction 13: Loss
# Prediction 14: Loss
# Prediction 15: Loss
# Prediction 16: Loss
# Prediction 17: Loss
# Prediction 18: Loss
# Prediction 19: Loss
# Prediction 20: Loss
# Prediction 21: Loss
# Prediction 22: Loss
# Prediction 23: Loss
# Prediction 24: Loss
# Prediction 25: Loss
# Prediction 26: Loss
# Prediction 27: Loss
# Prediction 28: Loss
# Prediction 29: Loss
# Prediction 30: Loss
# Prediction 31: Loss
# Prediction 32: Loss
# Prediction 33: Loss
# Prediction 34: Loss
# Prediction 35: Loss
# Prediction 36: Loss
# Prediction 37: Loss
# Prediction 38: Loss
# Prediction 39: Loss
# Prediction 40: Loss
# Prediction 41: Loss
# Prediction 42: Loss
# Prediction 43: Loss
# Prediction 44: Loss
# Prediction 45: Loss
# Prediction 46: Loss
# Prediction 47: Loss
# Prediction 48: Loss
# Prediction 49: Loss
# Prediction 50: Loss
# Prediction 51: Loss
# Prediction 52: Loss
# Prediction 53: Loss
# Prediction 54: Loss
# Prediction 55: Loss
# Prediction 56: Loss
# Prediction 57: Loss
# Prediction 58: Loss
# Prediction 59: Loss
# Prediction 60: Loss
# Prediction 61: Loss
# Prediction 62: Loss
# Prediction 63: Loss
# Prediction 64: Loss
# Prediction 65: Loss
# Prediction 66: Loss
# Prediction 67: Loss
# Prediction 68: Loss
# Prediction 69: Loss
# Prediction 70: Loss
# Prediction 71: Loss

# %%
# Define a threshold for considering a trade profitable or in loss
profit_threshold = 0.02  # 2% profit
loss_threshold = -0.02   # 2% loss

# Calculate the price change from the previous day
price_change = true_values[1:] - true_values[:-1]

# Initialize lists to store trade decisions
trade_actions = []
trade_results = []

# Loop through the predictions and calculate trade decisions
for i in range(len(predictions)):
    if i == 0:
        trade_actions.append("HOLD")
        trade_results.append("N/A")
    else:
        if (predictions[i] - true_values[i-1]) / true_values[i-1] > profit_threshold:
            trade_actions.append("SELL")
            trade_results.append("Profit")
        elif (predictions[i] - true_values[i-1]) / true_values[i-1] < loss_threshold:
            trade_actions.append("SELL")
            trade_results.append("Loss")
        else:
            trade_actions.append("HOLD")
            trade_results.append("N/A")

# Print the trade decisions along with the results
for i in range(len(predictions)):
    print(f"Prediction: {predictions[i]:.2f}, True Value: {true_values[i]:.2f}, Action: {trade_actions[i]}, Result: {trade_results[i]}")
# Out:
# Prediction: 19505285898.88, True Value: 32156155847.28, Action: HOLD, Result: N/A
# Prediction: 19505291806.94, True Value: 33050246060.43, Action: SELL, Result: Loss
# Prediction: 19505386335.92, True Value: 32992568933.37, Action: SELL, Result: Loss
# Prediction: 19505478501.68, True Value: 33126581621.79, Action: SELL, Result: Loss
# Prediction: 19505536400.68, True Value: 32272414326.65, Action: SELL, Result: Loss
# Prediction: 19505398152.05, True Value: 32493515723.61, Action: SELL, Result: Loss
# Prediction: 19505391062.37, True Value: 32397917379.55, Action: SELL, Result: Loss
# Prediction: 19505343797.88, True Value: 31103785851.09, Action: SELL, Result: Loss
# Prediction: 19505269356.31, True Value: 30853809609.11, Action: SELL, Result: Loss
# Prediction: 19505206730.86, True Value: 30456166516.74, Action: SELL, Result: Loss
# Prediction: 19504975134.85, True Value: 27765216954.52, Action: SELL, Result: Loss
# Prediction: 19504744720.46, True Value: 27005231321.80, Action: SELL, Result: Loss
# Prediction: 19504540301.53, True Value: 27175376264.12, Action: SELL, Result: Loss
# Prediction: 19504372512.59, True Value: 26668693403.63, Action: SELL, Result: Loss
# Prediction: 19504047569.21, True Value: 23786904938.01, Action: SELL, Result: Loss
# Prediction: 19503747439.69, True Value: 25802307957.16, Action: SELL, Result: Loss
# Prediction: 19503650547.48, True Value: 27365804228.06, Action: SELL, Result: Loss
# Prediction: 19503644639.42, True Value: 26563570017.39, Action: SELL, Result: Loss
# Prediction: 19503591466.87, True Value: 26509127528.58, Action: SELL, Result: Loss
# Prediction: 19503561926.56, True Value: 28417444118.49, Action: SELL, Result: Loss
# Prediction: 19503683632.63, True Value: 32590409863.78, Action: SELL, Result: Loss
# Prediction: 19504041661.15, True Value: 33913203499.35, Action: SELL, Result: Loss
# Prediction: 19504368967.75, True Value: 33931663652.89, Action: SELL, Result: Loss
# Prediction: 19504625377.62, True Value: 32850181912.50, Action: SELL, Result: Loss
# Prediction: 19504829796.54, True Value: 33794914325.45, Action: SELL, Result: Loss
# Prediction: 19505059029.32, True Value: 32855452117.13, Action: SELL, Result: Loss
# Prediction: 19505164192.81, True Value: 33091150480.13, Action: SELL, Result: Loss
# Prediction: 19505290625.33, True Value: 32255322453.01, Action: SELL, Result: Loss
# Prediction: 19505289443.72, True Value: 31713527537.93, Action: SELL, Result: Loss
# Prediction: 19505297715.00, True Value: 34436383510.00, Action: SELL, Result: Loss
# Prediction: 19505463140.72, True Value: 34334480265.25, Action: SELL, Result: Loss
# Prediction: 19505597844.52, True Value: 34946799047.57, Action: SELL, Result: Loss
# Prediction: 19505686465.44, True Value: 35604866899.17, Action: SELL, Result: Loss
# Prediction: 19505817624.41, True Value: 35271771524.91, Action: SELL, Result: Loss
# Prediction: 19505894429.20, True Value: 34323823842.33, Action: SELL, Result: Loss
# Prediction: 19505882613.08, True Value: 34861702375.54, Action: SELL, Result: Loss
# Prediction: 19505796355.38, True Value: 31730677438.20, Action: SELL, Result: Loss
# Prediction: 19505690010.28, True Value: 31553956830.63, Action: SELL, Result: Loss
# Prediction: 19505640382.56, True Value: 31798237392.14, Action: SELL, Result: Loss
# Prediction: 19505594299.68, True Value: 32859426486.03, Action: SELL, Result: Loss
# Prediction: 19505569485.83, True Value: 32222555426.98, Action: SELL, Result: Loss
# Prediction: 19505530492.62, True Value: 32688619168.69, Action: SELL, Result: Loss
# Prediction: 19505490317.80, True Value: 37074752030.28, Action: SELL, Result: Loss
# Prediction: 19505699463.18, True Value: 37641935716.60, Action: SELL, Result: Loss
# Prediction: 19505828258.92, True Value: 34465886904.27, Action: SELL, Result: Loss
# Prediction: 19505848346.32, True Value: 34307916583.41, Action: SELL, Result: Loss
# Prediction: 19505881431.47, True Value: 34076076536.04, Action: SELL, Result: Loss
# Prediction: 19505884976.31, True Value: 33295421143.10, Action: SELL, Result: Loss
# Prediction: 19505864888.90, True Value: 33406167646.80, Action: SELL, Result: Loss
# Prediction: 19505842438.26, True Value: 33406167646.80, Action: SELL, Result: Loss
# Prediction: 19505822350.85, True Value: 32856472276.84, Action: SELL, Result: Loss
# Prediction: 19505792810.55, True Value: 32527791323.28, Action: SELL, Result: Loss
# Prediction: 19505704189.63, True Value: 32820707511.74, Action: SELL, Result: Loss
# Prediction: 19505652198.69, True Value: 32237616566.49, Action: SELL, Result: Loss
# Prediction: 19505542308.74, True Value: 31348849712.75, Action: SELL, Result: Loss
# Prediction: 19505450142.99, True Value: 32127193982.11, Action: SELL, Result: Loss
# Prediction: 19505422965.90, True Value: 32072432366.62, Action: SELL, Result: Loss
# Prediction: 19505391062.37, True Value: 31908679305.54, Action: SELL, Result: Loss
# Prediction: 19505376883.03, True Value: 32069966492.15, Action: SELL, Result: Loss
# Prediction: 19505389880.76, True Value: 32015103320.15, Action: SELL, Result: Loss
# Prediction: 19505361522.07, True Value: 31677845000.34, Action: SELL, Result: Loss
# Prediction: 19505322528.86, True Value: 31574882858.64, Action: SELL, Result: Loss
# Prediction: 19505303623.06, True Value: 31752391598.61, Action: SELL, Result: Loss
# Prediction: 19505261085.02, True Value: 30916495880.35, Action: SELL, Result: Loss
# Prediction: 19505197277.96, True Value: 30580006284.71, Action: SELL, Result: Loss
# Prediction: 19505134652.51, True Value: 30126591042.03, Action: SELL, Result: Loss
# Prediction: 19505085024.79, True Value: 30118037837.03, Action: SELL, Result: Loss
# Prediction: 19505037760.30, True Value: 30366529745.84, Action: SELL, Result: Loss
# Prediction: 19504986950.97, True Value: 31607253441.96, Action: SELL, Result: Loss
# Prediction: 19505014128.06, True Value: 31444438392.29, Action: SELL, Result: Loss
# Prediction: 19505044849.97, True Value: 31189926883.70, Action: SELL, Result: Loss
# Prediction: 19505053121.26, True Value: 30778349200.29, Action: SELL, Result: Loss
