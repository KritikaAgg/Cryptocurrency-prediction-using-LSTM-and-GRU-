# %%
import pandas as pd
import tensorflow as tf
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data = pd.read_csv('/content/drive/MyDrive/pbl research/ETH-USD.csv')
data.head()
# Out:
#          Date         Open         High          Low        Close  \
# 0  2022-08-11  1851.828369  1927.939209  1851.828369  1881.224121
# 1  2022-08-12  1880.899170  1957.552979  1860.083496  1957.246460
# 2  2022-08-13  1957.333984  2013.755737  1948.595215  1981.336548
# 3  2022-08-14  1981.782471  2022.791504  1919.010132  1936.802002
# 4  2022-08-15  1936.760498  2007.210327  1881.856812  1904.228149
#
#      Adj Close       Volume
# 0  1881.224121  23826986482
# 1  1957.246460  17168141904
# 2  1981.336548  16038975216
# 3  1936.802002  14062754456
# 4  1904.228149  20349931313

# %%
# Drop the 'Date' column as it's not needed for modeling
data = data.drop(columns=['Date'])

# %%
# Normalize the data using Min-Max scaling
scaler = MinMaxScaler()
data_scaled = scaler.fit_transform(data)

# %%
# Define the number of time steps for the GRU model
time_steps = 10  # You can adjust this according to your need

# %%
# Prepare data with time steps
X = []
y = []
for i in range(len(data_scaled) - time_steps):
    X.append(data_scaled[i:i+time_steps, :])
    y.append(data_scaled[i+time_steps, 1])  # Assuming 'Open' price is the target

X = np.array(X)
y = np.array(y)

# %%
# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# %%
# Build the LSTM model
model = Sequential()
model.add(LSTM(64, activation='relu', return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(LSTM(64, activation='relu', return_sequences=True))
model.add(LSTM(64, activation='relu', return_sequences=True))
model.add(LSTM(64, activation='relu', return_sequences=True))
model.add(LSTM(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])

# %%
# Train the model
model.fit(X_train, y_train, epochs=50, batch_size=64, validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 5/5 [==============================] - 10s 254ms/step - loss: 0.0657 - mae: 0.2134 - val_loss: 0.0674 - val_mae: 0.2515
# Epoch 2/50
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0644 - mae: 0.2125 - val_loss: 0.0719 - val_mae: 0.2603
# Epoch 3/50
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0630 - mae: 0.2116 - val_loss: 0.0758 - val_mae: 0.2677
# Epoch 4/50
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0603 - mae: 0.2078 - val_loss: 0.0748 - val_mae: 0.2659
# Epoch 5/50
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0544 - mae: 0.1983 - val_loss: 0.0668 - val_mae: 0.2502
# Epoch 6/50
# 5/5 [==============================] - 0s 53ms/step - loss: 0.0420 - mae: 0.1767 - val_loss: 0.0272 - val_mae: 0.1535
# Epoch 7/50
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0202 - mae: 0.1157 - val_loss: 0.0058 - val_mae: 0.0629
# Epoch 8/50
# 5/5 [==============================] - 0s 53ms/step - loss: 0.0180 - mae: 0.1002 - val_loss: 0.0049 - val_mae: 0.0561
# Epoch 9/50
# 5/5 [==============================] - 0s 47ms/step - loss: 0.0173 - mae: 0.1005 - val_loss: 0.0076 - val_mae: 0.0715
# Epoch 10/50
# 5/5 [==============================] - 0s 49ms/step - loss: 0.0160 - mae: 0.0961 - val_loss: 0.0060 - val_mae: 0.0569
# Epoch 11/50
# 5/5 [==============================] - 0s 51ms/step - loss: 0.0148 - mae: 0.0903 - val_loss: 0.0063 - val_mae: 0.0658
# Epoch 12/50
# 5/5 [==============================] - 0s 60ms/step - loss: 0.0139 - mae: 0.0888 - val_loss: 0.0057 - val_mae: 0.0582
# Epoch 13/50
# 5/5 [==============================] - 0s 50ms/step - loss: 0.0137 - mae: 0.0870 - val_loss: 0.0065 - val_mae: 0.0642
# Epoch 14/50
# 5/5 [==============================] - 0s 49ms/step - loss: 0.0132 - mae: 0.0874 - val_loss: 0.0066 - val_mae: 0.0655
# Epoch 15/50
# 5/5 [==============================] - 0s 49ms/step - loss: 0.0130 - mae: 0.0876 - val_loss: 0.0066 - val_mae: 0.0658
# Epoch 16/50
# 5/5 [==============================] - 0s 51ms/step - loss: 0.0126 - mae: 0.0867 - val_loss: 0.0064 - val_mae: 0.0646
# Epoch 17/50
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0122 - mae: 0.0847 - val_loss: 0.0096 - val_mae: 0.0844
# Epoch 18/50
# 5/5 [==============================] - 0s 53ms/step - loss: 0.0121 - mae: 0.0851 - val_loss: 0.0058 - val_mae: 0.0608
# Epoch 19/50
# 5/5 [==============================] - 0s 86ms/step - loss: 0.0115 - mae: 0.0816 - val_loss: 0.0072 - val_mae: 0.0706
# Epoch 20/50
# 5/5 [==============================] - 0s 81ms/step - loss: 0.0112 - mae: 0.0806 - val_loss: 0.0099 - val_mae: 0.0871
# Epoch 21/50
# 5/5 [==============================] - 0s 75ms/step - loss: 0.0104 - mae: 0.0780 - val_loss: 0.0047 - val_mae: 0.0530
# Epoch 22/50
# 5/5 [==============================] - 0s 81ms/step - loss: 0.0106 - mae: 0.0799 - val_loss: 0.0117 - val_mae: 0.0975
# Epoch 23/50
# 5/5 [==============================] - 0s 86ms/step - loss: 0.0105 - mae: 0.0791 - val_loss: 0.0212 - val_mae: 0.1351
# Epoch 24/50
# 5/5 [==============================] - 0s 82ms/step - loss: 0.0109 - mae: 0.0824 - val_loss: 0.0051 - val_mae: 0.0543
# Epoch 25/50
# 5/5 [==============================] - 0s 76ms/step - loss: 0.0099 - mae: 0.0762 - val_loss: 0.0086 - val_mae: 0.0813
# Epoch 26/50
# 5/5 [==============================] - 0s 87ms/step - loss: 0.0096 - mae: 0.0731 - val_loss: 0.0046 - val_mae: 0.0551
# Epoch 27/50
# 5/5 [==============================] - 0s 88ms/step - loss: 0.0089 - mae: 0.0724 - val_loss: 0.0064 - val_mae: 0.0701
# Epoch 28/50
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0087 - mae: 0.0728 - val_loss: 0.0093 - val_mae: 0.0876
# Epoch 29/50
# 5/5 [==============================] - 0s 86ms/step - loss: 0.0084 - mae: 0.0722 - val_loss: 0.0122 - val_mae: 0.1015
# Epoch 30/50
# 5/5 [==============================] - 0s 57ms/step - loss: 0.0082 - mae: 0.0691 - val_loss: 0.0076 - val_mae: 0.0778
# Epoch 31/50
# 5/5 [==============================] - 0s 60ms/step - loss: 0.0082 - mae: 0.0689 - val_loss: 0.0048 - val_mae: 0.0597
# Epoch 32/50
# 5/5 [==============================] - 0s 51ms/step - loss: 0.0076 - mae: 0.0662 - val_loss: 0.0051 - val_mae: 0.0619
# Epoch 33/50
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0072 - mae: 0.0649 - val_loss: 0.0106 - val_mae: 0.0950
# Epoch 34/50
# 5/5 [==============================] - 0s 52ms/step - loss: 0.0072 - mae: 0.0659 - val_loss: 0.0093 - val_mae: 0.0882
# Epoch 35/50
# 5/5 [==============================] - 0s 49ms/step - loss: 0.0073 - mae: 0.0661 - val_loss: 0.0152 - val_mae: 0.1142
# Epoch 36/50
# 5/5 [==============================] - 0s 51ms/step - loss: 0.0081 - mae: 0.0688 - val_loss: 0.0035 - val_mae: 0.0487
# Epoch 37/50
# 5/5 [==============================] - 0s 60ms/step - loss: 0.0066 - mae: 0.0622 - val_loss: 0.0037 - val_mae: 0.0506
# Epoch 38/50
# 5/5 [==============================] - 0s 52ms/step - loss: 0.0063 - mae: 0.0598 - val_loss: 0.0045 - val_mae: 0.0602
# Epoch 39/50
# 5/5 [==============================] - 0s 50ms/step - loss: 0.0070 - mae: 0.0652 - val_loss: 0.0032 - val_mae: 0.0382
# Epoch 40/50
# 5/5 [==============================] - 0s 50ms/step - loss: 0.0061 - mae: 0.0586 - val_loss: 0.0100 - val_mae: 0.0921
# Epoch 41/50
# 5/5 [==============================] - 0s 49ms/step - loss: 0.0064 - mae: 0.0617 - val_loss: 0.0100 - val_mae: 0.0923
# Epoch 42/50
# 5/5 [==============================] - 0s 55ms/step - loss: 0.0061 - mae: 0.0597 - val_loss: 0.0063 - val_mae: 0.0713
# Epoch 43/50
# 5/5 [==============================] - 0s 60ms/step - loss: 0.0057 - mae: 0.0581 - val_loss: 0.0115 - val_mae: 0.0993
# Epoch 44/50
# 5/5 [==============================] - 0s 60ms/step - loss: 0.0071 - mae: 0.0669 - val_loss: 0.0147 - val_mae: 0.1132
# Epoch 45/50
# 5/5 [==============================] - 0s 50ms/step - loss: 0.0061 - mae: 0.0605 - val_loss: 0.0047 - val_mae: 0.0491
# Epoch 46/50
# 5/5 [==============================] - 0s 53ms/step - loss: 0.0068 - mae: 0.0649 - val_loss: 0.0063 - val_mae: 0.0594
# Epoch 47/50
# 5/5 [==============================] - 0s 50ms/step - loss: 0.0070 - mae: 0.0640 - val_loss: 0.0030 - val_mae: 0.0454
# Epoch 48/50
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0056 - mae: 0.0576 - val_loss: 0.0048 - val_mae: 0.0613
# Epoch 49/50
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0054 - mae: 0.0563 - val_loss: 0.0031 - val_mae: 0.0439
# Epoch 50/50
# 5/5 [==============================] - 0s 53ms/step - loss: 0.0052 - mae: 0.0550 - val_loss: 0.0035 - val_mae: 0.0385

# %%
# Evaluate the model
loss, mae = model.evaluate(X_test, y_test)
print("Mean Absolute Error:", mae)
# Out:
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0035 - mae: 0.0385
# Mean Absolute Error: 0.03848329558968544

# %%
# Make predictions
predictions = model.predict(X_test)
# Out:
# 3/3 [==============================] - 1s 19ms/step

# %%
# Inverse transform the predictions and true values to the original scale
predictions = scaler.inverse_transform(np.concatenate((X_test[:, -1, 1:], predictions), axis=1))[:, -1]
true_values = scaler.inverse_transform(np.concatenate((X_test[:, -1, 1:], y_test.reshape(-1, 1)), axis=1))[:, -1]

# %%
import matplotlib.pyplot as plt

# %%
# Plot predictions vs. true values
plt.figure(figsize=(12, 6))
plt.plot(predictions, label='Predictions', color='red')
plt.plot(true_values, label='True Values', color='blue')
plt.title('Bitcoin Price Prediction')
plt.xlabel('Time Steps')
plt.ylabel('Open Price')
plt.legend()
plt.show()

# %%
# Calculate percentage error
percentage_error = (abs(predictions - true_values) / true_values) * 100

# Print the percentage error
for i, error in enumerate(percentage_error):
    print(f"Sample {i+1}: Percentage Error = {error:.2f}%")

# Calculate and print the mean percentage error
mean_percentage_error = np.mean(percentage_error)
print("\nMean Percentage Error:", mean_percentage_error)
# Out:
# Sample 1: Percentage Error = 3.78%
# Sample 2: Percentage Error = 0.89%
# Sample 3: Percentage Error = 0.71%
# Sample 4: Percentage Error = 0.05%
# Sample 5: Percentage Error = 2.32%
# Sample 6: Percentage Error = 0.10%
# Sample 7: Percentage Error = 2.28%
# Sample 8: Percentage Error = 0.62%
# Sample 9: Percentage Error = 1.69%
# Sample 10: Percentage Error = 0.79%
# Sample 11: Percentage Error = 6.67%
# Sample 12: Percentage Error = 6.02%
# Sample 13: Percentage Error = 0.37%
# Sample 14: Percentage Error = 4.25%
# Sample 15: Percentage Error = 0.64%
# Sample 16: Percentage Error = 11.74%
# Sample 17: Percentage Error = 19.64%
# Sample 18: Percentage Error = 18.60%
# Sample 19: Percentage Error = 16.93%
# Sample 20: Percentage Error = 16.96%
# Sample 21: Percentage Error = 22.57%
# Sample 22: Percentage Error = 20.79%
# Sample 23: Percentage Error = 14.58%
# Sample 24: Percentage Error = 5.96%
# Sample 25: Percentage Error = 4.76%
# Sample 26: Percentage Error = 0.58%
# Sample 27: Percentage Error = 0.77%
# Sample 28: Percentage Error = 3.20%
# Sample 29: Percentage Error = 3.24%
# Sample 30: Percentage Error = 7.85%
# Sample 31: Percentage Error = 9.20%
# Sample 32: Percentage Error = 9.60%
# Sample 33: Percentage Error = 8.73%
# Sample 34: Percentage Error = 4.36%
# Sample 35: Percentage Error = 0.58%
# Sample 36: Percentage Error = 0.59%
# Sample 37: Percentage Error = 7.24%
# Sample 38: Percentage Error = 4.33%
# Sample 39: Percentage Error = 0.46%
# Sample 40: Percentage Error = 6.45%
# Sample 41: Percentage Error = 5.62%
# Sample 42: Percentage Error = 6.02%
# Sample 43: Percentage Error = 15.98%
# Sample 44: Percentage Error = 14.46%
# Sample 45: Percentage Error = 3.22%
# Sample 46: Percentage Error = 0.14%
# Sample 47: Percentage Error = 2.01%
# Sample 48: Percentage Error = 3.31%
# Sample 49: Percentage Error = 1.12%
# Sample 50: Percentage Error = 1.26%
# Sample 51: Percentage Error = 1.70%
# Sample 52: Percentage Error = 2.01%
# Sample 53: Percentage Error = 4.09%
# Sample 54: Percentage Error = 2.08%
# Sample 55: Percentage Error = 0.64%
# Sample 56: Percentage Error = 2.37%
# Sample 57: Percentage Error = 2.37%
# Sample 58: Percentage Error = 1.88%
# Sample 59: Percentage Error = 1.68%
# Sample 60: Percentage Error = 0.29%
# Sample 61: Percentage Error = 1.64%
# Sample 62: Percentage Error = 2.35%
# Sample 63: Percentage Error = 1.23%
# Sample 64: Percentage Error = 2.82%
# Sample 65: Percentage Error = 2.40%
# Sample 66: Percentage Error = 2.36%
# Sample 67: Percentage Error = 1.53%
# Sample 68: Percentage Error = 0.15%
# Sample 69: Percentage Error = 4.08%
# Sample 70: Percentage Error = 2.73%
# Sample 71: Percentage Error = 0.97%
# Sample 72: Percentage Error = 1.57%
#
# Mean Percentage Error: 4.819444106002629

# %%
# Make predictions
predictions = model.predict(X_test)

# Inverse transform the predictions and true values to the original scale
predictions = scaler.inverse_transform(np.concatenate((X_test[:, -1, 1:], predictions), axis=1))[:, -1]
true_values = scaler.inverse_transform(np.concatenate((X_test[:, -1, 1:], y_test.reshape(-1, 1)), axis=1))[:, -1]

# Define a threshold for investment decision
invest_threshold = 1.0  # You can adjust this threshold as needed
# Out:
# 3/3 [==============================] - 0s 15ms/step

# %%
# Determine investment decisions and print the results
for i in range(len(predictions)):
    if predictions[i] > X_test[i, -1, 1] * invest_threshold:
        decision = "Invest"
    else:
        decision = "Do not invest"

    print(f"Predicted Price: {predictions[i]:.2f} | Current Open Price: {X_test[i, -1, 1]:.2f} | Decision: {decision}")
# Out:
# Predicted Price: 33371195237.28 | Current Open Price: 0.77 | Decision: Invest
# Predicted Price: 33344167038.00 | Current Open Price: 0.75 | Decision: Invest
# Predicted Price: 33226998364.34 | Current Open Price: 0.77 | Decision: Invest
# Predicted Price: 33108437751.42 | Current Open Price: 0.77 | Decision: Invest
# Predicted Price: 33022742502.45 | Current Open Price: 0.77 | Decision: Invest
# Predicted Price: 32460838598.95 | Current Open Price: 0.75 | Decision: Invest
# Predicted Price: 31660641310.23 | Current Open Price: 0.76 | Decision: Invest
# Predicted Price: 30909499836.92 | Current Open Price: 0.76 | Decision: Invest
# Predicted Price: 30331847404.96 | Current Open Price: 0.72 | Decision: Invest
# Predicted Price: 30214302978.60 | Current Open Price: 0.72 | Decision: Invest
# Predicted Price: 29617576961.22 | Current Open Price: 0.71 | Decision: Invest
# Predicted Price: 28630136664.21 | Current Open Price: 0.64 | Decision: Invest
# Predicted Price: 27275455997.11 | Current Open Price: 0.62 | Decision: Invest
# Predicted Price: 25534144702.41 | Current Open Price: 0.62 | Decision: Invest
# Predicted Price: 23938422219.93 | Current Open Price: 0.61 | Decision: Invest
# Predicted Price: 22773487215.93 | Current Open Price: 0.54 | Decision: Invest
# Predicted Price: 21990006196.13 | Current Open Price: 0.59 | Decision: Invest
# Predicted Price: 21623659124.93 | Current Open Price: 0.63 | Decision: Invest
| Current Open Price: 0.74 | Decision: Invest
# Predicted Price: 30885912492.59 | Current Open Price: 0.73 | Decision: Invest
# Predicted Price: 31260367787.25 | Current Open Price: 0.73 | Decision: Invest

# %%
# Calculate daily price changes for true values and predictions
true_price_changes = true_values[1:] - true_values[:-1]
predicted_price_changes = predictions[1:] - true_values[:-1]

# Define a threshold for considering a change as profitable or in loss
profit_threshold = 0.0  # You can adjust this threshold based on your preference

# Calculate whether the predictions are in profit or loss
profit_or_loss = np.where(predicted_price_changes > profit_threshold, 'Profit', 'Loss')

# Print whether each prediction is in profit or loss
for i in range(len(profit_or_loss)):
    print(f"Prediction {i+1}: {profit_or_loss[i]}")
# Out:
# Prediction 1: Profit
# Prediction 2: Profit
# Prediction 3: Profit
# Prediction 4: Loss
# Prediction 5: Profit
# Prediction 6: Loss
# Prediction 7: Loss
# Prediction 8: Loss
# Prediction 9: Loss
# Prediction 10: Loss
# Prediction 11: Profit
# Prediction 12: Profit
# Prediction 13: Loss
# Prediction 14: Loss
# Prediction 15: Loss
# Prediction 16: Loss
# Prediction 17: Loss
# Prediction 18: Loss
# Prediction 19: Loss
# Prediction 20: Loss
# Prediction 21: Loss
# Prediction 22: Loss
# Prediction 23: Loss
# Prediction 24: Loss
# Prediction 25: Loss
# Prediction 26: Profit
# Prediction 27: Profit
# Prediction 28: Profit
# Prediction 29: Profit
# Prediction 30: Loss
# Prediction 31: Loss
# Prediction 32: Loss
# Prediction 33: Loss
# Prediction 34: Loss
# Prediction 35: Profit
# Prediction 36: Loss
# Prediction 37: Profit
# Prediction 38: Profit
# Prediction 39: Loss
# Prediction 40: Loss
# Prediction 41: Loss
# Prediction 42: Loss
# Prediction 43: Loss
# Prediction 44: Loss
# Prediction 45: Loss
# Prediction 46: Profit
# Prediction 47: Profit
# Prediction 48: Profit
# Prediction 49: Loss
# Prediction 50: Loss
# Prediction 51: Loss
# Prediction 52: Loss
# Prediction 53: Loss
# Prediction 54: Loss
# Prediction 55: Profit
# Prediction 56: Loss
# Prediction 57: Loss
# Prediction 58: Loss
# Prediction 59: Loss
# Prediction 60: Profit
# Prediction 61: Profit
# Prediction 62: Profit
# Prediction 63: Profit
# Prediction 64: Profit
# Prediction 65: Profit
# Prediction 66: Profit
# Prediction 67: Profit
# Prediction 68: Loss
# Prediction 69: Loss
# Prediction 70: Loss
# Prediction 71: Profit

# %%
# Define a threshold for considering a trade profitable or in loss
profit_threshold = 0.02  # 2% profit
loss_threshold = -0.02   # 2% loss

# Calculate the price change from the previous day
price_change = true_values[1:] - true_values[:-1]

# Initialize lists to store trade decisions
trade_actions = []
trade_results = []

# Loop through the predictions and calculate trade decisions
for i in range(len(predictions)):
    if i == 0:
        trade_actions.append("HOLD")
        trade_results.append("N/A")
    else:
        if (predictions[i] - true_values[i-1]) / true_values[i-1] > profit_threshold:
            trade_actions.append("SELL")
            trade_results.append("Profit")
        elif (predictions[i] - true_values[i-1]) / true_values[i-1] < loss_threshold:
            trade_actions.append("SELL")
            trade_results.append("Loss")
        else:
            trade_actions.append("HOLD")
            trade_results.append("N/A")

# Print the trade decisions along with the results
for i in range(len(predictions)):
    print(f"Prediction: {predictions[i]:.2f}, True Value: {true_values[i]:.2f}, Action: {trade_actions[i]}, Result: {trade_results[i]}")
